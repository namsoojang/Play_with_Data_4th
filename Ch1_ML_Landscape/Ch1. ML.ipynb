# %% [markdown]
# # 머신러닝 분류

# %% [markdown]
# ## 1. 지도학습

# %% [markdown]
# <img src="supervised.png" width="60%">

# %% [markdown]
# ###  Y의 데이터 타입에 따라
#         - Classification(명목형 데이터)
#         - Regression(수치형 데이터)
#
# ###  지도학습 종류
#         - Regression
#         - SVM(Support Vector Machines)
#         - Randome Forests
#         - ....

# %% [markdown]
# ## 2. 비지도학습

# %% [markdown]
# <img src="unsupervised.png" width="60%">

# %% [markdown]
# ###  비지도학습 활용
#         - Clustering
#         - anomaly detection
#         - ....

# %% [markdown]
# ## 3. 준지도학습 : 지도학습 + 비지도학습
#      - ex) 구글 포토, 페이스북
#         - 사용자의 지인 중 닮은 사람?(비지도) + 직접 Tagging(지도)

# %% [markdown]
# ## 4. 강화학습
#     - 현재 Environment & 가능한 Action 中   Max(reward) or Min(penalty)  방법 학습

# %% [markdown]
# ## etc) 모델링(?) 간격에 따라 배치학습 / 온라인 학습 으로 분류하는 것도 가능..

# %% [markdown]
# # ※ Data Scientists 설문
#
#  - 평균 연령: 30.......
#  - 대부분.. Regression, Tree..
# <img src="ds.jpg" width="50%">

# %% [markdown]
# ## 샘플예제
#
# ### 1인당 GDP Vs 행복지수(Life satisfaction)

# %%
# 라이브러리 가져오기
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn.linear_model

# %%
# 데이터 불러오기1: Life satisfaction
oecd_bli = pd.read_csv("oecd_bli_2015.csv", thousands=',')

# %%
oecd_bli.head()
# Out:
#   LOCATION         Country INDICATOR                           Indicator  \
# 0      AUS       Australia   HO_BASE  Dwellings without basic facilities
# 1      AUT         Austria   HO_BASE  Dwellings without basic facilities
# 2      BEL         Belgium   HO_BASE  Dwellings without basic facilities
# 3      CAN          Canada   HO_BASE  Dwellings without basic facilities
# 4      CZE  Czech Republic   HO_BASE  Dwellings without basic facilities
#
#   MEASURE Measure INEQUALITY Inequality Unit Code        Unit  PowerCode Code  \
# 0       L   Value        TOT      Total        PC  Percentage               0
# 1       L   Value        TOT      Total        PC  Percentage               0
# 2       L   Value        TOT      Total        PC  Percentage               0
# 3       L   Value        TOT      Total        PC  Percentage               0
# 4       L   Value        TOT      Total        PC  Percentage               0
#
# ...

# %%
set(oecd_bli.INEQUALITY.values)
# {'HGH', 'LW', 'MN', 'TOT', 'WMN'}
#   high,  low,  man , total, woman
# Out:
# {'HGH', 'LW', 'MN', 'TOT', 'WMN'}

# %%
oecd_bli = oecd_bli[oecd_bli["INEQUALITY"]=="TOT"]  # 전체 자료만 사용함
oecd_bli = oecd_bli.pivot(index="Country", columns="Indicator", values="Value")  # 국가 / 항목별 실적 
oecd_bli.head()
# 국가별 / 항목별 행복 지수
# 참고1 https://stats.oecd.org/index.aspx?DataSetCode=BLI
# 참고2 https://gitvfd.github.io/ho-is-li-in-st/
# Out:
# Indicator  Air pollution  Assault rate  Consultation on rule-making  \
# Country
# Australia           13.0           2.1                         10.5
# Austria             27.0           3.4                          7.1
# Belgium             21.0           6.6                          4.5
# Brazil              18.0           7.9                          4.0
# Canada              15.0           1.3                         10.5
#
# Indicator  Dwellings without basic facilities  Educational attainment  \
# Country
# Australia                                 1.1                    76.0
# Austria                                   1.0                    83.0
# Belgium                                   2.0                    72.0
# Brazil                                    6.7                    45.0
# Canada                                    0.2                    89.0
#
# Indicator  Employees working very long hours  Employment rate  Homicide rate  \
# Country
# ...

# %%
oecd_bli.columns
# Out:
# Index(['Air pollution', 'Assault rate', 'Consultation on rule-making',
#        'Dwellings without basic facilities', 'Educational attainment',
#        'Employees working very long hours', 'Employment rate', 'Homicide rate',
#        'Household net adjusted disposable income',
#        'Household net financial wealth', 'Housing expenditure', 'Job security',
#        'Life expectancy', 'Life satisfaction', 'Long-term unemployment rate',
#        'Personal earnings', 'Quality of support network', 'Rooms per person',
#        'Self-reported health', 'Student skills',
#        'Time devoted to leisure and personal care', 'Voter turnout',
#        'Water quality', 'Years in education'],
#       dtype='object', name='Indicator')

# %%
# 데이터 불러오기2: 1인당 GDP
gdp_per_capita = pd.read_csv("gdp_per_capita.csv",thousands=',',delimiter='\t',
                             encoding='latin1', na_values="n/a")

# %%
gdp_per_capita.head()
# Out:
#                Country                                 Subject Descriptor  \
# 0          Afghanistan  Gross domestic product per capita, current prices
# 1              Albania  Gross domestic product per capita, current prices
# 2              Algeria  Gross domestic product per capita, current prices
# 3               Angola  Gross domestic product per capita, current prices
# 4  Antigua and Barbuda  Gross domestic product per capita, current prices
#
#           Units  Scale                      Country/Series-specific Notes  \
# 0  U.S. dollars  Units  See notes for:  Gross domestic product, curren...
# 1  U.S. dollars  Units  See notes for:  Gross domestic product, curren...
# 2  U.S. dollars  Units  See notes for:  Gross domestic product, curren...
# 3  U.S. dollars  Units  See notes for:  Gross domestic product, curren...
# 4  U.S. dollars  Units  See notes for:  Gross domestic product, curren...
#
#         2015  Estimates Start After
# 0    599.994                 2013.0
# ...

# %%
gdp_per_capita.set_index('Country', inplace = True)
gdp_per_capita.rename(columns={"2015": "GDP per capita"}, inplace=True)
gdp_per_capita.head()
# Out:
#                                                     Subject Descriptor  \
# Country
# Afghanistan          Gross domestic product per capita, current prices
# Albania              Gross domestic product per capita, current prices
# Algeria              Gross domestic product per capita, current prices
# Angola               Gross domestic product per capita, current prices
# Antigua and Barbuda  Gross domestic product per capita, current prices
#
#                             Units  Scale  \
# Country
# Afghanistan          U.S. dollars  Units
# Albania              U.S. dollars  Units
# Algeria              U.S. dollars  Units
# Angola               U.S. dollars  Units
# Antigua and Barbuda  U.S. dollars  Units
#
#                                          Country/Series-specific Notes  \
# Country
# Afghanistan          See notes for:  Gross domestic product, curren...
# Albania              See notes for:  Gross domestic product, curren...
# ...

# %%
# 데이터 합치기
full_country_stats = pd.merge(left=oecd_bli, right=gdp_per_capita,
                                  left_index=True, right_index=True)

# %%
full_country_stats.head()
# Out:
#            Air pollution  Assault rate  Consultation on rule-making  \
# Country
# Australia           13.0           2.1                         10.5
# Austria             27.0           3.4                          7.1
# Belgium             21.0           6.6                          4.5
# Brazil              18.0           7.9                          4.0
# Canada              15.0           1.3                         10.5
#
#            Dwellings without basic facilities  Educational attainment  \
# Country
# Australia                                 1.1                    76.0
# Austria                                   1.0                    83.0
# Belgium                                   2.0                    72.0
# Brazil                                    6.7                    45.0
# Canada                                    0.2                    89.0
#
#            Employees working very long hours  Employment rate  Homicide rate  \
# Country
# ...

# %%
full_country_stats.columns
# Out:
# Index(['Air pollution', 'Assault rate', 'Consultation on rule-making',
#        'Dwellings without basic facilities', 'Educational attainment',
#        'Employees working very long hours', 'Employment rate', 'Homicide rate',
#        'Household net adjusted disposable income',
#        'Household net financial wealth', 'Housing expenditure', 'Job security',
#        'Life expectancy', 'Life satisfaction', 'Long-term unemployment rate',
#        'Personal earnings', 'Quality of support network', 'Rooms per person',
#        'Self-reported health', 'Student skills',
#        'Time devoted to leisure and personal care', 'Voter turnout',
#        'Water quality', 'Years in education', 'Subject Descriptor', 'Units',
#        'Scale', 'Country/Series-specific Notes', 'GDP per capita',
#        'Estimates Start After'],
#       dtype='object')

# %%
full_country_stats = full_country_stats[["GDP per capita", 'Life satisfaction']]
full_country_stats.sort_values(by="GDP per capita", inplace=True)

# %%
full_country_stats
# Out:
#                  GDP per capita  Life satisfaction
# Country
# Brazil                 8669.998                7.0
# Mexico                 9009.280                6.7
# Russia                 9054.914                6.0
# Turkey                 9437.372                5.6
# Hungary               12239.894                4.9
# Poland                12495.334                5.8
# Chile                 13340.905                6.7
# Slovak Republic       15991.736                6.1
# Czech Republic        17256.918                6.5
# Estonia               17288.083                5.6
# Greece                18064.288                4.8
# Portugal              19121.592                5.1
# Slovenia              20732.482                5.7
# Spain                 25864.721                6.5
# Korea                 27195.197                5.8
# Italy                 29866.581                6.0
# Japan                 32485.545                5.9
# ...

# %%
# 데이터 학습 준비
X = np.c_[full_country_stats["GDP per capita"]]
y = np.c_[full_country_stats["Life satisfaction"]]

# %%
# 데이터 학습 준비(reshape 활용)
X_re = np.reshape(full_country_stats["GDP per capita"].values, (-1,1))
y_re = np.reshape(full_country_stats["Life satisfaction"].values, (-1,1))

# %%
import matplotlib
from matplotlib import font_manager, rc
import platform

if platform.system() == 'Windows':
# 윈도우인 경우
    font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)
else:    
# Mac 인 경우
    rc('font', family='AppleGothic')
    
matplotlib.rcParams['axes.unicode_minus'] = False   
#그래프에서 마이너스 기호가 표시되도록 하는 설정

# %%
# 데이터 시각화
ax = full_country_stats.plot(kind='scatter', x="GDP per capita", y='Life satisfaction')
ax.set(xlabel="삶의 만족도", ylabel="1인당 GDP")
plt.show()

# %%
# 선형 모델 선택
model = sklearn.linear_model.LinearRegression()

# 모델 훈련
model.fit(X_re, y_re)
# 데이터 학습 준비
# X = np.c_[full_country_stats["GDP per capita"]]
# y = np.c_[full_country_stats["Life satisfaction"]]
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# # 선형 모델 선택
# model = sklearn.linear_model.LinearRegression()

# # 모델 훈련
# model.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# 키프로스에 대한 예측
X_new = [[22587]]  # 키프로스 1인당 GDP
print(model.predict(X_new)) # 결과 [[ 5.96242338]]
# Out:
# [[6.28653637]]
